# %%
import pandas as pd
file = "./Dataset/spotify_mil.csv"
# sep = ","

# %%
df = pd.read_csv(file)

# %%
df.head(10)
# Out:
#                        id                    name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                 Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8         Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7        Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0               Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T   Sleep Now In the Fire  The Battle Of Los Angeles
# 5  2LXPNLSMAauNJfnC58lSqY    Born of a Broken Man  The Battle Of Los Angeles
# 6  3moeHk8eIajvUEzVocXukf          Born As Ghosts  The Battle Of Los Angeles
# 7  4llunZfVXv3NvUzXVB3VVL                   Maria  The Battle Of Los Angeles
# 8  21Mq0NzFoVRvOmLTOnJjng  Voice of the Voiceless  The Battle Of Los Angeles
# 9  6s2FgJbnnMwFTpWJZzvb6z    New Millennium Homes  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# ...

# %%
df[['key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
       'time_signature', 'year', 'release_date']].head()
# Out:
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    7    -5.399     1       0.0727       0.02610          0.000011    0.3560
# 1   11    -5.764     1       0.1880       0.01290          0.000071    0.1550
# 2    7    -5.424     1       0.4830       0.02340          0.000002    0.1220
# 3   11    -5.830     0       0.2370       0.16300          0.000004    0.1210
# 4    2    -6.729     1       0.0701       0.00162          0.105000    0.0789
#
#    valence    tempo  duration_ms  time_signature  year release_date
# 0    0.503  117.906       210133             4.0  1999   1999-11-02
# 1    0.489  103.680       206200             4.0  1999   1999-11-02
# 2    0.370  149.749       298893             4.0  1999   1999-11-02
# 3    0.574   96.752       213640             4.0  1999   1999-11-02
# 4    0.539  127.059       205600             4.0  1999   1999-11-02

# %%
df1=df.drop(['artist_ids','explicit','disc_number','key','mode','id','album_id'],axis=1)
df1.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  track_number  danceability  energy  loudness  \
# 0  ['Rage Against The Machine']             1         0.470   0.978    -5.399
# 1  ['Rage Against The Machine']             2         0.599   0.957    -5.764
# 2  ['Rage Against The Machine']             3         0.315   0.970    -5.424
# 3  ['Rage Against The Machine']             4         0.440   0.967    -5.830
# 4  ['Rage Against The Machine']             5         0.426   0.929    -6.729
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0727       0.02610          0.000011    0.3560    0.503  117.906
# ...

# %%
df1.columns
# Out:
# Index(['name', 'album', 'artists', 'track_number', 'danceability', 'energy',
#        'loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'year',
#        'release_date'],
#       dtype='object')

# %%
df2=df1.groupby(["album"])['danceability', 'energy',
       'loudness', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo','time_signature'].mean()
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_13880\4228132650.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2=df1.groupby(["album"])['danceability', 'energy',

# %%
df2.dtypes
# Out:
# danceability        float64
# energy              float64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature      float64
# dtype: object

# %%
df2[df2["danceability"]>0.9]
# Out:
#                                   danceability  energy  loudness  speechiness  \
# album
# 0 Atao                                  0.9170  0.2540   -13.557       0.3610
# 12345SEX                                0.9165  0.4645    -6.926       0.0459
# 2 Seater (feat. G-Eazy & Offset)        0.9715  0.6875    -4.317       0.0818
# 2 Weeks                                 0.9440  0.2630   -11.063       0.1290
# 200 km/h                                0.9040  0.6770    -6.413       0.1770
# ...                                        ...     ...       ...          ...
# Падать в грязь                          0.9090  0.7440    -5.416       0.0514
# Повезло                                 0.9110  0.8700    -6.134       0.2560
# Тянет к тебе                            0.9090  0.6350    -5.298       0.0718
# Фаталити                                0.9170  0.8560    -6.391       0.1340
# Фу-Фу-Фу!                               0.9710  0.6050    -7.830       0.2540
#
# ...
