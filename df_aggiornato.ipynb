# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # READING AND PREPROCESSING

# %%
df_new = pd.read_csv('./Dataset/spotify_mil.csv')

# %%
df_t = pd.read_csv('./Dataset/RYM_top_tracks.csv',delimiter=";",encoding='windows-1252')

# %%
df_t = df_t.rename(columns={"Title":"name","Singer":"artists"})

# %%
df_new2 = df_new.drop(['id','album_id','artist_ids','disc_number','explicit','time_signature'],axis=1)

# %% [markdown]
# # FILTERING

# %%
filtered = []
filtered2 = []
df_filtered = pd.DataFrame(filtered)
df_final = pd.DataFrame(filtered2)

for i in range(df_t.shape[0]):
    df_final = pd.concat([df_final, df_new2[(df_new2["name"].str.contains(df_t["name"][i])) &
                                            (df_new2["artists"].str.contains(df_t["artists"][i]))]])

df_final

#get rid of multiple names for the same track and add missing columns "Ranking" and "Critic Score"
# Out:
# C:\Users\39331\AppData\Local\Temp/ipykernel_4260/1824956914.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_final = pd.concat([df_final, df_new2[(df_new2["name"].str.contains(df_t["name"][i])) &
#                                                       name  \
# 875387                                      God Only Knows
# 605678                         How to Disappear Completely
# 845277   Running Up That Hill (A Deal With God) - 2018 ...
# 870840                  "Heroes" - Live, Glastonbury, 2000
# 1028150                     "Heroes" - Klax Mix Radio Edit
# ...                                                    ...
# 775226                 Carry Me Ohio (Alternative Version)
# 1167494                      A Forest (Bestival Live 2011)
# 1171485    A Forest - Tree Mix; 2018 Remaster [Remastered]
# 1172755                           A Forest - 2006 Remaster
# 1172773                A Forest - Live in France June 1980
#
# ...

# %%
df_final[df_final["name"].str.contains("Karma Police")]
# Out:
#                 name         album        artists  track_number  danceability  \
# 605694  Karma Police  Karma Police  ['Radiohead']             1          0.36
# 605732  Karma Police   OK Computer  ['Radiohead']             6          0.36
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 605694   0.501    7    -9.129     1       0.0258        0.0638
# 605732   0.501    7    -9.129     1       0.0258        0.0638
#
#         instrumentalness  liveness  valence   tempo  duration_ms  year  \
# 605694          0.000093     0.172    0.324  74.807       264067  1997
# 605732          0.000093     0.172    0.324  74.807       264067  1997
#
#        release_date
# 605694   1997-08-25
# 605732   1997-05-28
