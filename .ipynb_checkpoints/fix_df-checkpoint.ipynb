# %%
import pandas as pd
file = "./Dataset/Top5000.csv"
# sep = ","

# %%
df = pd.read_csv(file)

# %%
df.head(10)
# Out:
#    Unnamed: 0                       ars_name           rel_date  \
# 0           0                      Radiohead       16 June 1997
# 1           1                     Pink Floyd  12 September 1975
# 2           2                   King Crimson    10 October 1969
# 3           3                      Radiohead     3 October 2000
# 4           4                 Kendrick Lamar      15 March 2015
# 5           5            My Bloody Valentine    4 November 1991
# 6           6                     Pink Floyd      23 March 1973
# 7           7                    The Beatles  26 September 1969
# 8           8  The Velvet Underground & Nico      12 March 1967
# 9           9                    David Bowie       16 June 1972
#
#                                               gens  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3          Art Rock, Experimental Rock, Electronic
# ...

# %%
df['Ranking'] = df['Unnamed: 0'] + 1
df.set_index('Ranking')
# Out:
#          Unnamed: 0            ars_name           rel_date  \
# Ranking
# 1                 0           Radiohead       16 June 1997
# 2                 1          Pink Floyd  12 September 1975
# 3                 2        King Crimson    10 October 1969
# 4                 3           Radiohead     3 October 2000
# 5                 4      Kendrick Lamar      15 March 2015
# ...             ...                 ...                ...
# 4398           4397          John Hiatt           May 1987
# 4399           4398           Catharsis               1999
# 4400           4399            Gracious       17 July 1970
# 4401           4400  And Also the Trees   12 November 2007
# 4402           4401     Minnie Riperton        22 May 1975
#
#                                                     gens  \
# Ranking
# 1                             Alternative Rock, Art Rock
# 2                             Progressive Rock, Art Rock
# 3                             Progressive Rock, Art Rock
# ...

# %%
df1=df.drop(['Unnamed: 0'],axis=1)
df2=df1.set_index('Ranking')
df2
# Out:
#                    ars_name           rel_date  \
# Ranking
# 1                 Radiohead       16 June 1997
# 2                Pink Floyd  12 September 1975
# 3              King Crimson    10 October 1969
# 4                 Radiohead     3 October 2000
# 5            Kendrick Lamar      15 March 2015
# ...                     ...                ...
# 4398             John Hiatt           May 1987
# 4399              Catharsis               1999
# 4400               Gracious       17 July 1970
# 4401     And Also the Trees   12 November 2007
# 4402        Minnie Riperton        22 May 1975
#
#                                                     gens  \
# Ranking
# 1                             Alternative Rock, Art Rock
# 2                             Progressive Rock, Art Rock
# 3                             Progressive Rock, Art Rock
# 4                Art Rock, Experimental Rock, Electronic
# 5        Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
# ...

# %%
df2.columns
# Out:
# Index(['ars_name', 'rel_date', 'gens', 'descs', 'avg_rat', 'num_rat',
#        'num_revs', 'album', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# df2=df1.groupby(["album"])['danceability', 'energy',
#        'loudness', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo','time_signature'].mean()

# %%
df2.dtypes
# Out:
# ars_name             object
# rel_date             object
# gens                 object
# descs                object
# avg_rat             float64
# num_rat              object
# num_revs              int64
# album                object
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# duration_ms         float64
# time_signature      float64
# dtype: object

# %% [markdown]
# # INIZIA DA QUA

# %%
df_new = pd.read_csv('./Dataset/spotify_mil.csv')

# %%
sep2=";"

# %%
df_t = pd.read_csv('./Dataset/RYM_top_tracks.csv',delimiter=sep2,encoding='windows-1252')

# %%
df_t=df_t.rename(columns={"Title":"name","Singer":"artists"})

# %%
df_t.head(20)
# Out:
#                                     name                        artists  \
# 0                    Wouldn't It Be Nice                 The Beach Boys
# 1                         God Only Knows                 The Beach Boys
# 2            Sinnerman (Parts One & Two)                    Nina Simone
# 3            How to Disappear Completely                      Radiohead
# 4                         When You Sleep            My Bloody Valentine
# 5                   Running Up That Hill                      Kate Bush
# 6                          Under the Ivy                      Kate Bush
# 7                                 Heroes                    David Bowie
# 8              Strawberry Fields Forever                    The Beatles
# 9   There Is a Light That Never Goes Out                     The Smiths
# 10                         Life on Mars?                    David Bowie
# 11            The Man Who Sold the World                    David Bowie
# ...

# %%
df_t['artists'] = "[\'" + df_t['artists']  + "\']"

# %%
df_t.head()
# Out:
#                           name                  artists  Ranking Critic Score
# 0          Wouldn't It Be Nice       ['The Beach Boys']        1            1
# 1               God Only Knows       ['The Beach Boys']        1            1
# 2  Sinnerman (Parts One & Two)          ['Nina Simone']        2  0,990825688
# 3  How to Disappear Completely            ['Radiohead']        3  0,981651376
# 4               When You Sleep  ['My Bloody Valentine']        4  0,972477064

# %%
df_new.columns
# Out:
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'],
#       dtype='object')

# %%
df_new2=df_new.drop(['id','album_id','artist_ids','disc_number','explicit','time_signature'],axis=1)

# %%
# df_t LEFT
# df_new2 RIGHT

# %%
# df_new2["new_col"] = str(df_new2["artists"][0])

# %%
df_new2.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  track_number  danceability  energy  key  \
# 0  ['Rage Against The Machine']             1         0.470   0.978    7
# 1  ['Rage Against The Machine']             2         0.599   0.957   11
# 2  ['Rage Against The Machine']             3         0.315   0.970    7
# 3  ['Rage Against The Machine']             4         0.440   0.967   11
# 4  ['Rage Against The Machine']             5         0.426   0.929    2
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -5.399     1       0.0727       0.02610          0.000011    0.3560
# ...

# %%
result=pd.merge(df_t, df_new2,how='left', on=['name','artists'])
display(result)
# Out:
#                                    name                      artists  Ranking  \
# 0                   Wouldn't It Be Nice           ['The Beach Boys']        1
# 1                        God Only Knows           ['The Beach Boys']        1
# 2           Sinnerman (Parts One & Two)              ['Nina Simone']        2
# 3           How to Disappear Completely                ['Radiohead']        3
# 4                        When You Sleep      ['My Bloody Valentine']        4
# ..                                  ...                          ...      ...
# 161                            A Forest                 ['The Cure']      106
# 162                 Beach Life-in-Death        ['Car Seat Headrest']      107
# 163  They Reminisce Over You (T.R.O.Y.)  ['Pete Rock & C.L. Smooth']      108
# 164                            Pyramids              ['Frank Ocean']      109
# 165                 Unfinished Sympathy                  ['Massive']      110
#
# ...

# %%
no_nan = result.dropna()
no_nan.head()
# Out:
#                            name             artists  Ranking Critic Score  \
# 1                God Only Knows  ['The Beach Boys']        1            1
# 3   How to Disappear Completely       ['Radiohead']        3  0,981651376
# 12           Once in a Lifetime   ['Talking Heads']       10  0,917431193
# 13                 Karma Police       ['Radiohead']       11  0,908256881
# 14                 Karma Police       ['Radiohead']       11  0,908256881
#
#                 album  track_number  danceability  energy  key  loudness  ...  \
# 1   The Wrecking Crew           3.0         0.474   0.415  9.0   -10.135  ...
# 3               Kid A           4.0         0.167   0.302  6.0   -11.644  ...
# 12    Remain in Light           4.0         0.646   0.880  2.0    -7.753  ...
# 13       Karma Police           1.0         0.360   0.501  7.0    -9.129  ...
# 14        OK Computer           6.0         0.360   0.501  7.0    -9.129  ...
#
# ...
